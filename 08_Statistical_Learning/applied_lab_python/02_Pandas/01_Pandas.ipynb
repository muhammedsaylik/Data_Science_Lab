# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
data = pd.Series([0.25, 0.50, 0.75, 1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data[1]
# Out:
# np.float64(0.5)

# %%
data[1:3]
# Out:
# 1    0.50
# 2    0.75
# dtype: float64

# %% [markdown]
# - pandas serilerinin indexlerini kendimiz tanımlayabiliriz index olarak sayılar veya  harfler kullanılabilir

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index =['a', 'b', 'c', 'd'])
data['a']
# Out:
# np.float64(0.25)

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index =[1, 4, 7, 2])
data[7]
# Out:
# np.float64(0.75)

# %% [markdown]
# ###  Series as specialized dictionary

# %%
population_dict = {'California': 38332521,
                        'Texas': 26448193,
                     'New York': 19651127,
                      'Florida': 19552860,
                     'Illinois': 12882135}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
type(population)
# Out:
# pandas.core.series.Series

# %%
population['California']
# Out:
# np.int64(38332521)

# %%
population['California':'Illinois']
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %% [markdown]
# ### Constructing Series objects

# %%
pd.Series([2, 4, 6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
pd.Series(5, index=[100, 200, 300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd.Series({2:'a', 1:'b', 3:'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
pd.Series({2:'a', 1:'b', 3:'c'}, index=[3, 2])
# Out:
# 3    c
# 2    a
# dtype: object

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
 'Florida': 170312, 'Illinois': 149995}

# %%
area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({'population': population, 'area': area }) # pd series i dataframe çevirme
states
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
states.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
states.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %%
yaş = [23, 43, 12, 34, 56, 10]
saç_rengi = ['siyah', 'sarı', 'kumral', 'siyah', 'kızıl', 'sarı']
isim = ['Emre', 'Çınar', 'Kemal', 'Esma', 'Ceyda', 'Ali']

data1 = pd.DataFrame({'isim': isim, 'Yaş':yaş, 'saç_rengi':saç_rengi})
data1
# Out:
#     isim  Yaş saç_rengi
# 0   Emre   23     siyah
# 1  Çınar   43      sarı
# 2  Kemal   12    kumral
# 3   Esma   34     siyah
# 4  Ceyda   56     kızıl
# 5    Ali   10      sarı

# %% [markdown]
# ###  DataFrame as specialized dictionary

# %%
states['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %% [markdown]
# ### Constructing DataFrame objects

# %%
pd.DataFrame(population, columns=['population'])
# Out:
#             population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %%
data = [{'a':i, 'b': 2*i} for i in range(3)]
pd.DataFrame(data)
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
pd.DataFrame({'a':'a', 'b':2}, {'c':3, 'd':4})
# Out:
#    a  b
# c  a  2
# d  a  2

# %%
pd.DataFrame({
    'population': population, 
    'area': area
})
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
pd.DataFrame(
    np.random.rand(3,2),
    columns=['foo', 'bar'],
    index=['a', 'b', 'c']
)
# Out:
#         foo       bar
# a  0.197420  0.716622
# b  0.327725  0.068800
# c  0.478593  0.876441

# %%
A = np.zeros(3, dtype=[('A', 'i8'), ('B', 'f8')])
A
# Out:
# array([(0, 0.), (0, 0.), (0, 0.)], dtype=[('A', '<i8'), ('B', '<f8')])

# %%
pd.DataFrame(A)
# Out:
#    A    B
# 0  0  0.0
# 1  0  0.0
# 2  0  0.0

# %% [markdown]
# ### The Pandas Index Object

# %%
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Index([2, 3, 5, 7, 11], dtype='int64')

# %%
ind[1]
# Out:
# np.int64(3)

# %%
ind[::2]
# Out:
# Index([2, 5, 11], dtype='int64')

# %%
print(ind.shape, ind.dtype, ind.ndim, ind.size) # shape verinin boyutu, dtype verinin tiğini, ndim kaç boyutlu veri, size toplam eleman sayısını verir
# Out:
# (5,) int64 1 5

# %%
indA = pd.Index([1, 3, 5, 7, 9]) # Tek boyutlu etiketli dizi tek değişkenli veri tutmak zaman serisi oluşturmak vb işlemler için kullanılır
indB = pd.Index([2, 3, 5, 7, 11])

indA & indB
# Out:
# Index([0, 3, 5, 7, 9], dtype='int64')

# %%
indA | indB
# Out:
# Index([3, 3, 5, 7, 11], dtype='int64')

# %%
indA ^ indB
# Out:
# Index([3, 0, 0, 0, 2], dtype='int64')

# %% [markdown]
# ### Data Selection in Series

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index = ['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# np.float64(0.5)

# %%
'a' in data
# Out:
# True

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
list[data.items()]
# Out:
# list[<zip object at 0x000001CFF43CFD40>]

# %%
data['e'] = 1.25
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %% [markdown]
# ###  Series as one-dimensional array

# %%
data['a': 'c']
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %%
data[0:2]
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
data[(data > 0.3) & (data < 0.8)]
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
data[['a', 'e']]
# Out:
# a    0.25
# e    1.25
# dtype: float64

# %% [markdown]
# ###  Indexers: loc, iloc, and ix

# %%
data = pd.Series(['a', 'b', 'c'], index = [1, 3, 5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
data[1]
# Out:
# 'a'

# %%
data[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# .loc  index ve kolon adına göre veri seçer
# .iloc numaraya göre seçer 0 dan başlayan sıra numarasına göre seçer
#
# benzetme : bir apartman düşün loc = daire numarasına göre çağırmak "A-5 numaralı daire", iloc = sıraya göre çağırmak "soldan 3. daire"

# %%
data.loc[1]
# Out:
# 'a'

# %%
data.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %%
data.iloc[1]
# Out:
# 'b'

# %%
data.iloc[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# ### Data Selection in DataFrame

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
 'New York': 141297, 'Florida': 170312,
 'Illinois': 149995})

pop = pd.Series({'California': 38332521, 'Texas': 26448193,
 'New York': 19651127, 'Florida': 19552860,
 'Illinois': 12882135})

data = pd.DataFrame({'area': area, 'pop': pop})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.area is data['area']
# Out:
# True

# %%
data.pop is data['pop']
# Out:
# False

# %%
data['density'] = data['pop'] / data['area']

# %%
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %% [markdown]
# ### DataFrame as two-dimensional array

# %%
data.values
# Out:
# array([[4.23967000e+05, 3.83325210e+07, 9.04139261e+01],
#        [6.95662000e+05, 2.64481930e+07, 3.80187404e+01],
#        [1.41297000e+05, 1.96511270e+07, 1.39076746e+02],
#        [1.70312000e+05, 1.95528600e+07, 1.14806121e+02],
#        [1.49995000e+05, 1.28821350e+07, 8.58837628e+01]])

# %%
data.T  # taranspoz almak satırları sütuna sütunları satıra çevirmek
# Out:
#            California         Texas      New York       Florida      Illinois
# area     4.239670e+05  6.956620e+05  1.412970e+05  1.703120e+05  1.499950e+05
# pop      3.833252e+07  2.644819e+07  1.965113e+07  1.955286e+07  1.288214e+07
# density  9.041393e+01  3.801874e+01  1.390767e+02  1.148061e+02  8.588376e+01

# %%
data.values[0]
# Out:
# array([4.23967000e+05, 3.83325210e+07, 9.04139261e+01])

# %%
data['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.iloc[:3, :2]
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127

# %%
data.loc[:'Illinois', :'pop']
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data.loc[data.density > 100 , ['pop', 'density']]
# Out:
#                pop     density
# New York  19651127  139.076746
# Florida   19552860  114.806121

# %%
data.iloc[0, 2] = 90
data
# Out:
#               area       pop     density
# California  423967  38332521   90.000000
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %% [markdown]
# ### Index Preservation

# %%
rng = np.random.RandomState(42)
ser = pd.Series(rng.randint(0, 10, 4))
ser
# Out:
# 0    6
# 1    3
# 2    7
# 3    4
# dtype: int32

# %%
df = pd.DataFrame(rng.randint(0, 10, (3, 4)), columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B  C  D
# 0  6  9  2  6
# 1  7  4  3  7
# 2  7  2  5  4

# %%
np.exp(ser)
# Out:
# 0     403.428793
# 1      20.085537
# 2    1096.633158
# 3      54.598150
# dtype: float64

# %%
np.sin(df * np.pi / 4)
# Out:
#           A             B         C             D
# 0 -1.000000  7.071068e-01  1.000000 -1.000000e+00
# 1 -0.707107  1.224647e-16  0.707107 -7.071068e-01
# 2 -0.707107  1.000000e+00 -0.707107  1.224647e-16

# %% [markdown]
# ### Index Alignment

# %%
area = pd.Series({'Alaska': 1723337, 'Texas': 695662,
 'California': 423967}, name='area')
population = pd.Series({'California': 38332521, 'Texas': 26448193,
 'New York': 19651127}, name='population')

# %%
population / area
# Out:
# Alaska              NaN
# California    90.413926
# New York            NaN
# Texas         38.018740
# dtype: float64

# %%
A = pd.Series([2, 4, 6], index =[0, 1, 2])
B = pd.Series([1, 3, 5], index=[1, 2, 3])
A+B
# Out:
# 0    NaN
# 1    5.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
A.add(B, fill_value=0)
# Out:
# 0    2.0
# 1    5.0
# 2    9.0
# 3    5.0
# dtype: float64

# %%
A = pd.DataFrame(rng.randint(0, 20, (2, 2)), columns=list('AB'))
A
# Out:
#    A   B
# 0  1  11
# 1  5   1

# %%
B = pd.DataFrame(rng.randint(0, 10, (3,3)), columns=list('BAC'))

# %%
A
# Out:
#    A   B
# 0  1  11
# 1  5   1

# %%
B
# Out:
#    B  A  C
# 0  3  8  2
# 1  4  2  6
# 2  4  8  6

# %%
A+B
# Out:
#      A     B   C
# 0  9.0  14.0 NaN
# 1  7.0   5.0 NaN
# 2  NaN   NaN NaN

# %%
fill = A.stack().mean() # stack() sütunları satıra çeviri
A.add(B, fill_value=fill) # add() "+" operatörünün akıllı halidir ortak indise sahip değerleri toplar ör A için    1+8 = 9, B için 8+11 = 14
# Out:
#       A     B     C
# 0   9.0  14.0   6.5
# 1   7.0   5.0  10.5
# 2  12.5   8.5  10.5

# %% [markdown]
# ### Operations Between DataFrame and Series

# %%
A  = rng.randint(10, size=(3, 4))
A
# Out:
# array([[1, 3, 8, 1],
#        [9, 8, 9, 4],
#        [1, 3, 6, 7]], dtype=int32)

# %%
A - A[0] # 0. satırı tüm satırlardan çıkarır
# Out:
# array([[ 0,  0,  0,  0],
#        [ 8,  5,  1,  3],
#        [ 0,  0, -2,  6]], dtype=int32)

# %%
df = pd.DataFrame(A, columns=list('QRST'))
df - df.iloc[0]
# Out:
#    Q  R  S  T
# 0  0  0  0  0
# 1  8  5  1  3
# 2  0  0 -2  6

# %%
df.subtract(df['R'], axis=0) # sayısal verilerde çıkarma işlemi yapar (index e göre hizayalarak)
# Out:
#    Q  R  S  T
# 0 -2  0  5 -2
# 1  1  0  1 -4
# 2 -2  0  3  4

# %%
halfrow = df.iloc[0, ::2]
halfrow
# Out:
# Q    1
# S    8
# Name: 0, dtype: int32

# %%
df - halfrow
# Out:
#      Q   R    S   T
# 0  0.0 NaN  0.0 NaN
# 1  8.0 NaN  1.0 NaN
# 2  0.0 NaN -2.0 NaN
